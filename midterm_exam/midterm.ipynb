# %% [markdown]
# # Midterm Exam for CSC 180

# %% [markdown]
# 1. Lab 8: add model score to GUI & save models
# 2. Lab 8 copy but with a twist, use saved models instead of algorithm
# 3. Lab 2: model score, decision tree, and random forest
