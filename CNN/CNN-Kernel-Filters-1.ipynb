# %%
# ================================================================
#   CNN KERNELS, FILTERS, AND FEATURE MAP VISUALIZATION NOTEBOOK
# ================================================================

# This notebook demonstrates:
#   ✔ How Conv2D kernels & filters work
#   ✔ How to extract kernel weights from a CNN
#   ✔ How to visualize kernels
#   ✔ How to visualize feature maps produced by filters
#
# Requirements:
#   - TensorFlow
#   - Matplotlib
#   - An image file in the working directory
# ================================================================

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models

print("TensorFlow version:", tf.__version__)
